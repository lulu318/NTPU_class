# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = sns.load_dataset("iris")

sns.pairplot(data=data, hue="species", diag_kind="hist")
plt.suptitle("多變數散佈圖與直方圖（Pairplot）", y=1.02)
plt.show()
