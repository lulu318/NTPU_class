# %%
import requests
import json
import pandas as pd

keyword = "可口可樂" 
url = 'https://ecshweb.pchome.com.tw/search/v3.3/all/results?q='+keyword+'&page='+str(1)+'&sort=sale/dc'
#請求網站
list_req = requests.get(url)
#將整個網站的程式碼爬下來
getdata = json.loads(list_req.content)

# %%
getdata
# Out:
# {'QTime': 442,
#  'totalRows': 73,
#  'totalPage': 4,
#  'range': {'min': '', 'max': ''},
#  'cateName': '',
#  'q': '可口可樂',
#  'subq': '',
#  'token': [],
#  'isMust': 1,
#  'prods': [{'Id': 'DBAB12-A46597285',
#    'cateId': 'DBAB12',
#    'picS': '/items/DBAB12A46597285/000001_1707300959.jpg',
#    'picB': '/items/DBAB12A46597285/000001_1707300959.jpg',
#    'name': '【Coca-Cola 】易開罐250ml (24入/箱)',
#    'describe': '【Coca-Cola 可口可樂】易開罐250ml (24入/箱)\\r\\n新舊包裝隨機出貨，如可接受再購買，其內容物則無任何差異\r\n★小型易開罐，勁享輕鬆時刻\r\n★擋不住的暢快口感\r\n★勁享美食，就要Coke\r\n\r\n★參考其他口味 (Wording WIP) \r\n【可口可樂 易開罐 235ml (8入)】\r\n【可口可樂 易開罐 330ml (6入)】\r\n【可口可樂 易開罐 330ml (24入)】\r\n【可口可樂 寶特瓶 350ml (24入)】',
#    'price': 259,
#    'originPrice': 259,
#    'author': '',
#    'brand': '',
#    'publishDate': '',
#    'isPChome': 1,
#    'isNC17': 0,
#    'couponActid': [],
#    'BU': 'ec'},
#   {'Id': 'DBAB12-A47622311',
#    'cateId': 'DBAB12',
#    'picS': '/items/DBAB12A47622311/000001_1754901030.jpg',
# ...
