# %%
import requests
from urllib.parse import quote
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36',
    }  
keyword = "可口可樂" 
url = f"https://tw.bid.yahoo.com/search/auction/product?p={quote(keyword)}&clv=0"

res = requests.get(url, headers=headers)

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.title.text)
print(soup.title)
# Out:
# 可口可樂-優惠推薦 2025年8月 | Yahoo拍賣
# <title>可口可樂-優惠推薦 2025年8月 | Yahoo拍賣</title>

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
import re, json, html
script_tag = soup.find_all("script", type="mime/invalid")[0].get_text()
cleaned = re.sub(r',\s*([\]}])', r'\1', script_tag)
data = json.loads(script_tag)
data
# Out:
# {'pjaxLoading': False,
#  'search': {'searched': True,
#   'isSearchLoading': False,
#   'isAppendLoading': False,
#   'count': 60,
#   'utherUrl': 'https://uther.paas.ec.yahoo.com:4443/api/uther/v1?aoffset=0&cid=0&clv=0&format=json&isSocialPackageEnabled=1&isTestStoreIncluded=0&isdedup=1&p=%E5%8F%AF%E5%8F%A3%E5%8F%AF%E6%A8%82&pdoffset=0&pdpsz=30&pg=1&poffset=0&property=auction&psz=60&qt=product&searchChain=auction_cb&sort=rel&source=pc&spaceId=2092111218',
#   'ecsearch': {'hits': [{'ec_property': '4',
#      'ec_hashtags': [],
#      'ec_seller': 'hanwa88',
#      'ec_endtime': '2145916800',
#      'ec_min_price': '25.0',
#      'ec_listprice': '25.0',
#      'ec_model_tags': [],
#      'ec_image': 'https://img.yec.tw/cl/api/res/1.2/nrC789hdEPH3jSUcYdyLLQ--/YXBwaWQ9eXR3YXVjdGlvbnNlcnZpY2U7aD00MDA7cT04NTtyb3RhdGU9YXV0bzt3PTM4Mw--/https://img.yec.tw/ob/image/5b5155bd-6c3c-43db-bda6-3726e78df4c0.jpg#383x400',
#      'ec_cat5': '',
#      'ec_buy_count': '7',
# ...

# %%
import pandas as pd
pd.DataFrame(data['search']['ecsearch']['hits'])
# Out:
#    ec_property                                        ec_hashtags  \
# 0            4                                                 []
# 1            4                              [{'item': '泡泡瑪特迷你台'}]
# 2            4  [{'item': '限量'}, {'item': '可口可樂'}, {'item': '收...
# 3            4                                                 []
# 4            4                                                 []
# 5            4                                                 []
# 6            4                                                 []
# 7            4                                                 []
# 8            4                                                 []
# 9            4                                                 []
# 10           4  [{'item': '可口可樂冰塊'}, {'item': 'cocacola'}, {'i...
# 11           4  [{'item': 'CocaCola'}, {'item': '可口可樂'}, {'ite...
# 12           4                                                 []
# ...

# %%
script_tag
# Out:
# '{"pjaxLoading":false,"search":{"searched":true,"isSearchLoading":false,"isAppendLoading":false,"count":60,"utherUrl":"https://uther.paas.ec.yahoo.com:4443/api/uther/v1?aoffset=0&cid=0&clv=0&format=json&isSocialPackageEnabled=1&isTestStoreIncluded=0&isdedup=1&p=%E5%8F%AF%E5%8F%A3%E5%8F%AF%E6%A8%82&pdoffset=0&pdpsz=30&pg=1&poffset=0&property=auction&psz=60&qt=product&searchChain=auction_cb&sort=rel&source=pc&spaceId=2092111218","ecsearch":{"hits":[{"ec_property":"4","ec_hashtags":[],"ec_seller":"hanwa88","ec_endtime":"2145916800","ec_min_price":"25.0","ec_listprice":"25.0","ec_model_tags":[],"ec_image":"https://img.yec.tw/cl/api/res/1.2/nrC789hdEPH3jSUcYdyLLQ--/YXBwaWQ9eXR3YXVjdGlvbnNlcnZpY2U7aD00MDA7cT04NTtyb3RhdGU9YXV0bzt3PTM4Mw--/https://img.yec.tw/ob/image/5b5155bd-6c3c-43db-bda6-3726e78df4c0.jpg#383x400","ec_cat5":"","ec_buy_count":"7","ec_shelf_status":"1","ec_description":"COCA\xa0COLA可口可樂\xa0限量\xa0購物袋 數量有限，下標前請先詢問","ec_store_id":"1346648","ec_paytype":[],"ec_location":"台南市","e
# ...
